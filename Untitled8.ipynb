# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi-coder439/PythonFsp/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr = []

n = int(input("Enter number of elements: "))

for i in range(n):
    num = int(input("Enter element: "))
    arr.append(num)

largest = max(arr)

arr.remove(largest)

second_largest = max(arr)

print("Largest element:", largest)
print("Second largest element:", second_largest)
# Out:
# Enter number of elements: 5
# Enter element: 13
# Enter element: 55
# Enter element: 56
# Enter element: 99
# Enter element: 55
# Largest element: 99
# Second largest element: 56

# %%
arr = [1, 2, 3, 4, 5]

reversed_arr = arr[::-1]

print("Reversed array:", reversed_arr)
# Out:
# Reversed array: [5, 4, 3, 2, 1]

# %%
arr = []

n = int(input("Enter number of elements: "))

for i in range(n):
    num = int(input("Enter element: "))
    arr.append(num)

if arr == sorted(arr):
    print("Array is sorted in ascending order")
else:
    print("Array is not sorted in ascending order")
# Out:
# Enter number of elements: 5
# Enter element: 1
# Enter element: 2
# Enter element: 3
# Enter element: 6
# Enter element: 5
# Array is not sorted in ascending order

# %%
arr = [1, 2, 3, 4, 5]

if arr == sorted(arr):
    print("Array is sorted in ascending order")
else:
    print("Array is not sorted in ascending order")
# Out:
# Array is sorted in ascending order

# %%
arr = [1, 2,  4, 5]

n = len(arr) + 1

expected_sum = n * (n + 1) // 2
actual_sum = sum(arr)

missing_number = expected_sum - actual_sum

print("Missing number is:", missing_number)
# Out:
# Missing number is: 3
